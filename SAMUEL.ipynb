# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#Uppgift B.
athlete = pd.read_csv("athlete_events.csv")
noc = pd.read_csv("noc_regions.csv")

df_lander = pd.DataFrame({"NOC": noc["NOC"].unique()})
df_lander
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
# a)
print('Hur många länder som är med i datan:')
antal_länder = df['NOC'].nunique()
antal_länder
# Out:
# Hur många länder som är med i datan:
# 230

# %%
# b)
print('Vilka länder som är med (förkortningar):')
land_lista = sorted(df['NOC'].dropna().unique())
land_lista
# Out:
# Vilka länder som är med (förkortningar):
# ['AFG',
#  'AHO',
#  'ALB',
#  'ALG',
#  'AND',
#  'ANG',
#  'ANT',
#  'ANZ',
#  'ARG',
#  'ARM',
#  'ARU',
#  'ASA',
#  'AUS',
#  'AUT',
#  'AZE',
#  'BAH',
#  'BAN',
#  'BAR',
#  'BDI',
#  'BEL',
#  'BEN',
#  'BER',
#  'BHU',
#  'BIH',
#  'BIZ',
#  'BLR',
#  'BOH',
#  'BOL',
#  'BOT',
#  'BRA',
#  'BRN',
#  'BRU',
#  'BUL',
#  'BUR',
#  'CAF',
#  'CAM',
#  'CAN',
#  'CAY',
#  'CGO',
#  'CHA',
#  'CHI',
#  'CHN',
#  'CIV',
#  'CMR',
#  'COD',
#  'COK',
#  'COL',
#  'COM',
#  'CPV',
#  'CRC',
#  'CRO',
#  'CRT',
#  'CUB',
#  'CYP',
#  'CZE',
#  'DEN',
#  'DJI',
#  'DMA',
#  'DOM',
#  'ECU',
#  'EGY',
#  'ERI',
#  'ESA',
#  'ESP',
#  'EST',
#  'ETH',
#  'EUN',
#  'FIJ',
#  'FIN',
#  'FRA',
#  'FRG',
#  'FSM',
#  'GAB',
#  'GAM',
#  'GBR',
#  'GBS',
#  'GDR',
#  'GEO',
#  'GEQ',
#  'GER',
#  'GHA',
#  'GRE',
#  'GRN',
#  'GUA',
#  'GUI',
#  'GUM',
#  'GUY',
#  'HAI',
#  'HKG',
#  'HON',
#  'HUN',
#  'INA',
#  'IND',
#  'IOA',
#  'IRI',
# ...

# %%
# c)
print('Vilka sporter som är med:')
sport_lista = sorted(df['Sport'].dropna().unique())
sport_lista
# Out:
# Vilka sporter som är med:
# ['Aeronautics',
#  'Alpine Skiing',
#  'Alpinism',
#  'Archery',
#  'Art Competitions',
#  'Athletics',
#  'Badminton',
#  'Baseball',
#  'Basketball',
#  'Basque Pelota',
#  'Beach Volleyball',
#  'Biathlon',
#  'Bobsleigh',
#  'Boxing',
#  'Canoeing',
#  'Cricket',
#  'Croquet',
#  'Cross Country Skiing',
#  'Curling',
#  'Cycling',
#  'Diving',
#  'Equestrianism',
#  'Fencing',
#  'Figure Skating',
#  'Football',
#  'Freestyle Skiing',
#  'Golf',
#  'Gymnastics',
#  'Handball',
#  'Hockey',
#  'Ice Hockey',
#  'Jeu De Paume',
#  'Judo',
#  'Lacrosse',
#  'Luge',
#  'Military Ski Patrol',
#  'Modern Pentathlon',
#  'Motorboating',
#  'Nordic Combined',
#  'Polo',
#  'Racquets',
#  'Rhythmic Gymnastics',
#  'Roque',
#  'Rowing',
#  'Rugby',
#  'Rugby Sevens',
#  'Sailing',
#  'Shooting',
#  'Short Track Speed Skating',
#  'Skeleton',
#  'Ski Jumping',
#  'Snowboarding',
#  'Softball',
#  'Speed Skating',
#  'Swimming',
#  'Synchronized Swimming',
# ...

# %%
# d)
print('Medaljtyper som finns:')
df['Medal'].unique()
df['Medal'].unique()
# Out:
# Medaljtyper som finns:
# array([nan, 'Gold', 'Bronze', 'Silver'], dtype=object)

# %%
# e)
print('Statistik för åldern:')
ålder = df['Age']
ålder.describe()
# Out:
# Statistik för åldern:
# count    261642.000000
# mean         25.556898
# std           6.393561
# min          10.000000
# 25%          21.000000
# 50%          24.000000
# 75%          28.000000
# max          97.000000
# Name: Age, dtype: float64

# %%
# f)

# %%
# g)
gender_counts = df['Sex'].value_counts()

plt.figure(figsize=(6,6))
plt.pie(
    gender_counts.values,
    labels=gender_counts.index,
    autopct='%1.1f%%',
    startangle=90,
    colors=['lightblue', 'lightcoral']
)
plt.title('Könsfördelning i datasetet')
plt.show()

# %%
# h)
medaljer = df[df["Medal"].notna()]

top_10_lander = medaljer["NOC"].value_counts().head(10)

plt.figure(figsize=(10,6))
plt.bar(top_10_lander.index, top_10_lander.values, color='gold')
plt.title('Topp 10 länder med flest medaljer')
plt.xlabel('Land (NOC)')
plt.ylabel('Antal medaljer')
plt.show()

# %%
# i)
